# %%
#importing the necessary libraries for plotting
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

#librariers to build models and checking accuracy
import sklearn
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

#library to split data
from sklearn.model_selection import train_test_split

#library for EDA
from scipy.stats import zscore

#library for hyperparameter tuning
from sklearn.model_selection import GridSearchCV 

#Library for saving data
import pickle

#other libraries
import pandas as pd
import numpy as np

#libraries for regularisation
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# question: how does HR Analytics help in analyzing attrition
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to
# applying analytic processes to the human resource department of an organization in the hope
# of improving employee performance and therefore getting a better return on investment. HR
# analytics does not just deal with gathering data on employee efficiency. Instead, it aims to
# provide insight into each process by gathering data and then using it to make relevant
# decisions about how to improve these processes

# %% [markdown]
# Attrition in human resources refers to the gradual loss of employees overtime

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head(100)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# ..  ...       ...                ...        ...                     ...
# 95   54        No      Travel_Rarely       1217  Research & Development
# 96   24        No      Travel_Rarely       1353                   Sales
# 97   28        No         Non-Travel        120                   Sales
# 98   58        No      Travel_Rarely        682                   Sales
# 99   44        No         Non-Travel        489  Research & Development
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                  1          2     Life Sciences              1
# 1                  8          1     Life Sciences              1
# 2                  2          2             Other              1
# 3                  3          4     Life Sciences              1
# 4                  2          1           Medical              1
# ..               ...        ...               ...            ...
# 95                 2          4  Technical Degree              1
# 96                 3          2             Other              1
# 97                 4          3           Medical              1
# 98                10          4           Medical              1
# 99                23          3           Medical              1
#
#     EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0                1                        2  Female          94
# 1                2                        3    Male          61
# 2                4                        4    Male          92
# 3                5                        4  Female          56
# 4                7                        1    Male          40
# ..             ...                      ...     ...         ...
# 95             126                        1  Female          60
# 96             128                        1  Female          33
# 97             129                        2    Male          43
# 98             131                        4    Male          37
# 99             132                        2    Male          67
#
#     JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0                3         2        Sales Executive                4
# 1                2         2     Research Scientist                2
# 2                2         1  Laboratory Technician                3
# 3                3         1     Research Scientist                3
# 4                3         1  Laboratory Technician                2
# ..             ...       ...                    ...              ...
# 95               3         3      Research Director                3
# 96               3         2        Sales Executive                3
# 97               3         2        Sales Executive                3
# 98               3         4        Sales Executive                3
# 99               3         2  Laboratory Technician                2
#
#    MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 0         Single           5993        19479                   8      Y
# 1        Married           5130        24907                   1      Y
# 2         Single           2090         2396                   6      Y
# 3        Married           2909        23159                   1      Y
# 4        Married           3468        16632                   9      Y
# ..           ...            ...          ...                 ...    ...
# 95       Married          13549        24001                   9      Y
# 96       Married           4999        17519                   0      Y
# 97       Married           4221         8863                   1      Y
# 98        Single          13872        24409                   0      Y
# 99       Married           2042        25043                   4      Y
#
#    OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0       Yes                 11                  3                         1
# 1        No                 23                  4                         4
# 2       Yes                 15                  3                         2
# 3       Yes                 11                  3                         3
# 4        No                 12                  3                         4
# ..      ...                ...                ...                       ...
# 95       No                 12                  3                         1
# 96       No                 21                  4                         1
# 97       No                 15                  3                         2
# 98       No                 13                  3                         3
# 99       No                 12                  3                         3
#
#     StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0              80                 0                  8                      0
# 1              80                 1                 10                      3
# 2              80                 0                  7                      3
# 3              80                 0                  8                      3
# 4              80                 1                  6                      3
# ..            ...               ...                ...                    ...
# 95             80                 1                 16                      5
# 96             80                 1                  4                      2
# 97             80                 0                  5                      3
# 98             80                 0                 38                      1
# 99             80                 1                 17                      3
#
#     WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                 1               6                   4
# 1                 3              10                   7
# 2                 3               0                   0
# 3                 3               8                   7
# 4                 3               2                   2
# ..              ...             ...                 ...
# 95                1               4                   3
# 96                2               3                   2
# 97                4               5                   4
# 98                2              37                  10
# 99                4               3                   2
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 0                         0                     5
# 1                         1                     7
# 2                         0                     0
# 3                         3                     0
# 4                         2                     2
# ..                      ...                   ...
# 95                        0                     3
# 96                        0                     2
# 97                        0                     4
# 98                        1                     8
# 99                        1                     2
#
# [100 rows x 35 columns]

# %% [markdown]
# There is 35 columns in the dataset

# %%
#show all columns in dataframe
pd.set_option('display.max_columns', None)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0                  1                        2  Female          94
# 1                  2                        3    Male          61
# 2                  4                        4    Male          92
# 3                  5                        4  Female          56
# 4                  7                        1    Male          40
# ...              ...                      ...     ...         ...
# 1465            2061                        3    Male          41
# 1466            2062                        4    Male          42
# 1467            2064                        2    Male          87
# 1468            2065                        4    Male          63
# 1469            2068                        2    Male          82
#
#       JobInvolvement  JobLevel                    JobRole  JobSatisfaction  \
# 0                  3         2            Sales Executive                4
# 1                  2         2         Research Scientist                2
# 2                  2         1      Laboratory Technician                3
# 3                  3         1         Research Scientist                3
# 4                  3         1      Laboratory Technician                2
# ...              ...       ...                        ...              ...
# 1465               4         2      Laboratory Technician                4
# 1466               2         3  Healthcare Representative                1
# 1467               4         2     Manufacturing Director                2
# 1468               2         2            Sales Executive                2
# 1469               4         2      Laboratory Technician                3
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 0           Single           5993        19479                   8      Y
# 1          Married           5130        24907                   1      Y
# 2           Single           2090         2396                   6      Y
# 3          Married           2909        23159                   1      Y
# 4          Married           3468        16632                   9      Y
# ...            ...            ...          ...                 ...    ...
# 1465       Married           2571        12290                   4      Y
# 1466       Married           9991        21457                   4      Y
# 1467       Married           6142         5174                   1      Y
# 1468       Married           5390        13243                   2      Y
# 1469       Married           4404        10228                   2      Y
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0         Yes                 11                  3                         1
# 1          No                 23                  4                         4
# 2         Yes                 15                  3                         2
# 3         Yes                 11                  3                         3
# 4          No                 12                  3                         4
# ...       ...                ...                ...                       ...
# 1465       No                 17                  3                         3
# 1466       No                 15                  3                         1
# 1467      Yes                 20                  4                         2
# 1468       No                 14                  3                         4
# 1469       No                 12                  3                         1
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0                80                 0                  8
# 1                80                 1                 10
# 2                80                 0                  7
# 3                80                 0                  8
# 4                80                 1                  6
# ...             ...               ...                ...
# 1465             80                 1                 17
# 1466             80                 1                  9
# 1467             80                 1                  6
# 1468             80                 0                 17
# 1469             80                 0                  6
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                         0                1               6
# 1                         3                3              10
# 2                         3                3               0
# 3                         3                3               8
# 4                         3                3               2
# ...                     ...              ...             ...
# 1465                      3                3               5
# 1466                      5                3               7
# 1467                      0                3               6
# 1468                      3                2               9
# 1469                      3                4               4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                      4                        0                     5
# 1                      7                        1                     7
# 2                      0                        0                     0
# 3                      7                        3                     0
# 4                      2                        2                     2
# ...                  ...                      ...                   ...
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# Many of the data in the columns seem to have only one unique value

# %% [markdown]
# # Checking columns with single unique values

# %%
#value counts of some  datas

print("Standardhours value count",df["StandardHours"].value_counts())

print(" ")
print("BusinessTravel",df["BusinessTravel"].value_counts())

print(" ")
print("Department",df["Department"].value_counts())

print(" ")
print("EmployeeCount",df["EmployeeCount"].value_counts())
# Out:
# Standardhours value count 80    1470
# Name: StandardHours, dtype: int64
#
# BusinessTravel Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
# Department Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
#
# EmployeeCount 1    1470
# Name: EmployeeCount, dtype: int64

# %%
#Since StandardHours and EmployeeCount one unique value, dropping it
df=df.drop(columns=["StandardHours","EmployeeCount"])

# %%
#Employee number is an unnecessary column which we can drop
df=df.drop(columns=['EmployeeNumber'])

# %%
cat_cols = df.select_dtypes(include=object).columns.tolist()
(pd.DataFrame(
    df[cat_cols]
    .melt(var_name='column', value_name='value')
    .value_counts())
.rename(columns={0: 'counts'})
.sort_values(by=['column', 'counts']))
# Out:
#                                           counts
# column         value
# Attrition      Yes                           237
#                No                           1233
# BusinessTravel Non-Travel                    150
#                Travel_Frequently             277
#                Travel_Rarely                1043
# Department     Human Resources                63
#                Sales                         446
#                Research & Development        961
# EducationField Human Resources                27
#                Other                          82
#                Technical Degree              132
#                Marketing                     159
#                Medical                       464
#                Life Sciences                 606
# Gender         Female                        588
#                Male                          882
# JobRole        Human Resources                52
#                Research Director              80
#                Sales Representative           83
#                Manager                       102
#                Healthcare Representative     131
#                Manufacturing Director        145
#                Laboratory Technician         259
#                Research Scientist            292
#                Sales Executive               326
# MaritalStatus  Divorced                      327
#                Single                        470
#                Married                       673
# Over18         Y                            1470
# OverTime       Yes                           416
#                No                           1054

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   object
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  Over18                    1470 non-null   object
#  20  OverTime                  1470 non-null   object
#  21  PercentSalaryHike         1470 non-null   int64
#  22  PerformanceRating         1470 non-null   int64
#  23  RelationshipSatisfaction  1470 non-null   int64
#  24  StockOptionLevel          1470 non-null   int64
#  25  TotalWorkingYears         1470 non-null   int64
#  26  TrainingTimesLastYear     1470 non-null   int64
#  27  WorkLifeBalance           1470 non-null   int64
#  28  YearsAtCompany            1470 non-null   int64
#  29  YearsInCurrentRole        1470 non-null   int64
#  30  YearsSinceLastPromotion   1470 non-null   int64
#  31  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(23), object(9)
# memory usage: 367.6+ KB

# %%
df.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# top     Research & Development               NaN          NaN  Life Sciences
# freq                       961               NaN          NaN            606
# mean                       NaN          9.192517     2.912925            NaN
# std                        NaN          8.106864     1.024165            NaN
# min                        NaN          1.000000     1.000000            NaN
# 25%                        NaN          2.000000     2.000000            NaN
# 50%                        NaN          7.000000     3.000000            NaN
# 75%                        NaN         14.000000     4.000000            NaN
# max                        NaN         29.000000     5.000000            NaN
#
#         EnvironmentSatisfaction Gender   HourlyRate  JobInvolvement  \
# count               1470.000000   1470  1470.000000     1470.000000
# unique                      NaN      2          NaN             NaN
# top                         NaN   Male          NaN             NaN
# freq                        NaN    882          NaN             NaN
# mean                   2.721769    NaN    65.891156        2.729932
# std                    1.093082    NaN    20.329428        0.711561
# min                    1.000000    NaN    30.000000        1.000000
# 25%                    2.000000    NaN    48.000000        2.000000
# 50%                    3.000000    NaN    66.000000        3.000000
# 75%                    4.000000    NaN    83.750000        3.000000
# max                    4.000000    NaN   100.000000        4.000000
#
#            JobLevel          JobRole  JobSatisfaction MaritalStatus  \
# count   1470.000000             1470      1470.000000          1470
# unique          NaN                9              NaN             3
# top             NaN  Sales Executive              NaN       Married
# freq            NaN              326              NaN           673
# mean       2.063946              NaN         2.728571           NaN
# std        1.106940              NaN         1.102846           NaN
# min        1.000000              NaN         1.000000           NaN
# 25%        1.000000              NaN         2.000000           NaN
# 50%        2.000000              NaN         3.000000           NaN
# 75%        3.000000              NaN         4.000000           NaN
# max        5.000000              NaN         4.000000           NaN
#
#         MonthlyIncome   MonthlyRate  NumCompaniesWorked Over18 OverTime  \
# count     1470.000000   1470.000000         1470.000000   1470     1470
# unique            NaN           NaN                 NaN      1        2
# top               NaN           NaN                 NaN      Y       No
# freq              NaN           NaN                 NaN   1470     1054
# mean      6502.931293  14313.103401            2.693197    NaN      NaN
# std       4707.956783   7117.786044            2.498009    NaN      NaN
# min       1009.000000   2094.000000            0.000000    NaN      NaN
# 25%       2911.000000   8047.000000            1.000000    NaN      NaN
# 50%       4919.000000  14235.500000            2.000000    NaN      NaN
# 75%       8379.000000  20461.500000            4.000000    NaN      NaN
# max      19999.000000  26999.000000            9.000000    NaN      NaN
#
#         PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# count         1470.000000        1470.000000               1470.000000
# unique                NaN                NaN                       NaN
# top                   NaN                NaN                       NaN
# freq                  NaN                NaN                       NaN
# mean            15.209524           3.153741                  2.712245
# std              3.659938           0.360824                  1.081209
# min             11.000000           3.000000                  1.000000
# 25%             12.000000           3.000000                  2.000000
# 50%             14.000000           3.000000                  3.000000
# 75%             18.000000           3.000000                  4.000000
# max             25.000000           4.000000                  4.000000
#
#         StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count        1470.000000        1470.000000            1470.000000
# unique               NaN                NaN                    NaN
# top                  NaN                NaN                    NaN
# freq                 NaN                NaN                    NaN
# mean            0.793878          11.279592               2.799320
# std             0.852077           7.780782               1.289271
# min             0.000000           0.000000               0.000000
# 25%             0.000000           6.000000               2.000000
# 50%             1.000000          10.000000               3.000000
# 75%             1.000000          15.000000               3.000000
# max             3.000000          40.000000               6.000000
#
#         WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count       1470.000000     1470.000000         1470.000000
# unique              NaN             NaN                 NaN
# top                 NaN             NaN                 NaN
# freq                NaN             NaN                 NaN
# mean           2.761224        7.008163            4.229252
# std            0.706476        6.126525            3.623137
# min            1.000000        0.000000            0.000000
# 25%            2.000000        3.000000            2.000000
# 50%            3.000000        5.000000            3.000000
# 75%            3.000000        9.000000            7.000000
# max            4.000000       40.000000           18.000000
#
#         YearsSinceLastPromotion  YearsWithCurrManager
# count               1470.000000           1470.000000
# unique                      NaN                   NaN
# top                         NaN                   NaN
# freq                        NaN                   NaN
# mean                   2.187755              4.123129
# std                    3.222430              3.568136
# min                    0.000000              0.000000
# 25%                    0.000000              2.000000
# 50%                    1.000000              3.000000
# 75%                    3.000000              7.000000
# max                   15.000000             17.000000

# %% [markdown]
# OBSERVATIONS:
#
# 1.The difference between mean and median is large in MonthlyIncome,StockOptionLevel,YearsAtCompany and small in other numerical datas
#
# 2.Null values arent seen

# %%
#checking nan
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
#removing duplicate values
df.drop_duplicates(inplace=True)

# %%
#finding numerical datas

df.select_dtypes(include=["number"]).columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
num=df[{'Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
       'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager'}]
num
# Out:
#       StockOptionLevel  MonthlyIncome  NumCompaniesWorked  YearsInCurrentRole  \
# 0                    0           5993                   8                   4
# 1                    1           5130                   1                   7
# 2                    0           2090                   6                   0
# 3                    0           2909                   1                   7
# 4                    1           3468                   9                   2
# ...                ...            ...                 ...                 ...
# 1465                 1           2571                   4                   2
# 1466                 1           9991                   4                   7
# 1467                 1           6142                   1                   2
# 1468                 0           5390                   2                   6
# 1469                 0           4404                   2                   3
#
#       JobLevel  YearsAtCompany  JobInvolvement  EnvironmentSatisfaction  \
# 0            2               6               3                        2
# 1            2              10               2                        3
# 2            1               0               2                        4
# 3            1               8               3                        4
# 4            1               2               3                        1
# ...        ...             ...             ...                      ...
# 1465         2               5               4                        3
# 1466         3               7               2                        4
# 1467         2               6               4                        2
# 1468         2               9               2                        4
# 1469         2               4               4                        2
#
#       Education  PercentSalaryHike  YearsSinceLastPromotion  MonthlyRate  \
# 0             2                 11                        0        19479
# 1             1                 23                        1        24907
# 2             2                 15                        0         2396
# 3             4                 11                        3        23159
# 4             1                 12                        2        16632
# ...         ...                ...                      ...          ...
# 1465          2                 17                        0        12290
# 1466          1                 15                        1        21457
# 1467          3                 20                        0         5174
# 1468          3                 14                        0        13243
# 1469          3                 12                        1        10228
#
#       YearsWithCurrManager  TotalWorkingYears  JobSatisfaction  \
# 0                        5                  8                4
# 1                        7                 10                2
# 2                        0                  7                3
# 3                        0                  8                3
# 4                        2                  6                2
# ...                    ...                ...              ...
# 1465                     3                 17                4
# 1466                     7                  9                1
# 1467                     3                  6                2
# 1468                     8                 17                2
# 1469                     2                  6                3
#
#       TrainingTimesLastYear  WorkLifeBalance  PerformanceRating  Age  \
# 0                         0                1                  3   41
# 1                         3                3                  4   49
# 2                         3                3                  3   37
# 3                         3                3                  3   33
# 4                         3                3                  3   27
# ...                     ...              ...                ...  ...
# 1465                      3                3                  3   36
# 1466                      5                3                  3   39
# 1467                      0                3                  4   27
# 1468                      3                2                  3   49
# 1469                      3                4                  3   34
#
#       HourlyRate  RelationshipSatisfaction  DailyRate  DistanceFromHome
# 0             94                         1       1102                 1
# 1             61                         4        279                 8
# 2             92                         2       1373                 2
# 3             56                         3       1392                 3
# 4             40                         4        591                 2
# ...          ...                       ...        ...               ...
# 1465          41                         3        884                23
# 1466          42                         1        613                 6
# 1467          87                         2        155                 4
# 1468          63                         4       1023                 2
# 1469          82                         1        628                 8
#
# [1470 rows x 23 columns]

# %%
num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1470 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   StockOptionLevel          1470 non-null   int64
#  1   MonthlyIncome             1470 non-null   int64
#  2   NumCompaniesWorked        1470 non-null   int64
#  3   YearsInCurrentRole        1470 non-null   int64
#  4   JobLevel                  1470 non-null   int64
#  5   YearsAtCompany            1470 non-null   int64
#  6   JobInvolvement            1470 non-null   int64
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Education                 1470 non-null   int64
#  9   PercentSalaryHike         1470 non-null   int64
#  10  YearsSinceLastPromotion   1470 non-null   int64
#  11  MonthlyRate               1470 non-null   int64
#  12  YearsWithCurrManager      1470 non-null   int64
#  13  TotalWorkingYears         1470 non-null   int64
#  14  JobSatisfaction           1470 non-null   int64
#  15  TrainingTimesLastYear     1470 non-null   int64
#  16  WorkLifeBalance           1470 non-null   int64
#  17  PerformanceRating         1470 non-null   int64
#  18  Age                       1470 non-null   int64
#  19  HourlyRate                1470 non-null   int64
#  20  RelationshipSatisfaction  1470 non-null   int64
#  21  DailyRate                 1470 non-null   int64
#  22  DistanceFromHome          1470 non-null   int64
# dtypes: int64(23)
# memory usage: 275.6 KB

# %% [markdown]
# All are integer datatypes

# %%
#visualising the relationship
plt.figure(figsize=(15,50))
graph=1

for column in num:
    if graph<=30:
        ax=plt.subplot(10,3,graph)
        sns.boxplot(num[column],orient='v')
        plt.xlabel(column,fontsize=10)
    graph+=1
    
plt.show()

# %% [markdown]
# Have explained the relationship between continous features and label after a few lines of code

# %% [markdown]
# # finding categorical datas

# %%
df.select_dtypes(exclude=["number"]).columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
cat=df[{'Attrition', 'EducationField', 'Gender','BusinessTravel','Department',
       'JobRole', 'MaritalStatus', 'OverTime'}]
cat
# Out:
#          BusinessTravel EducationField              Department OverTime  \
# 0         Travel_Rarely  Life Sciences                   Sales      Yes
# 1     Travel_Frequently  Life Sciences  Research & Development       No
# 2         Travel_Rarely          Other  Research & Development      Yes
# 3     Travel_Frequently  Life Sciences  Research & Development      Yes
# 4         Travel_Rarely        Medical  Research & Development       No
# ...                 ...            ...                     ...      ...
# 1465  Travel_Frequently        Medical  Research & Development       No
# 1466      Travel_Rarely        Medical  Research & Development       No
# 1467      Travel_Rarely  Life Sciences  Research & Development      Yes
# 1468  Travel_Frequently        Medical                   Sales       No
# 1469      Travel_Rarely        Medical  Research & Development       No
#
#      MaritalStatus                    JobRole Attrition  Gender
# 0           Single            Sales Executive       Yes  Female
# 1          Married         Research Scientist        No    Male
# 2           Single      Laboratory Technician       Yes    Male
# 3          Married         Research Scientist        No  Female
# 4          Married      Laboratory Technician        No    Male
# ...            ...                        ...       ...     ...
# 1465       Married      Laboratory Technician        No    Male
# 1466       Married  Healthcare Representative        No    Male
# 1467       Married     Manufacturing Director        No    Male
# 1468       Married            Sales Executive        No    Male
# 1469       Married      Laboratory Technician        No    Male
#
# [1470 rows x 8 columns]

# %%
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1470 entries, 0 to 1469
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   BusinessTravel  1470 non-null   object
#  1   EducationField  1470 non-null   object
#  2   Department      1470 non-null   object
#  3   OverTime        1470 non-null   object
#  4   MaritalStatus   1470 non-null   object
#  5   JobRole         1470 non-null   object
#  6   Attrition       1470 non-null   object
#  7   Gender          1470 non-null   object
# dtypes: object(8)
# memory usage: 103.4+ KB

# %% [markdown]
# All are categorical data

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="BusinessTravel",y="Attrition",data=df)
plt.show()

# %% [markdown]
# Atrrition is highest for those who travel frequently for buisness

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="EducationField",y="Attrition",data=df)
plt.show()

# %% [markdown]
# Attrition is highest for human resource related education background employee

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="Department",y="Attrition",data=df)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="OverTime",y="Attrition",data=df)
plt.show()

# %% [markdown]
# attrition is highest for those employees who worked overtime

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="MaritalStatus",y="Attrition",data=df)
plt.show()

# %% [markdown]
# Attrition is highest among single, then married men/women and then only divorced person

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="JobRole",y="Attrition",data=df)
plt.show()

# %% [markdown]
# Attrition was highest among a person who was in a sales representative

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="Gender",y="Attrition",data=df)
plt.show()

# %% [markdown]
# Attrition was higher among male that female

# %%
x=df.drop(["Attrition"],axis=1)
y=df["Attrition"]

# %% [markdown]
# # EDA on continous data

# %%
#checking for outliers
df.hist(figsize=(35,20),bins = 15)
plt.title("Features Distribution")
plt.show()

# %%
#scaling
scalar=StandardScaler()
x_scaled=scalar.fit_transform(num)

# %%
# reducing skewness
num.skew()
# Out:
# StockOptionLevel            0.968980
# MonthlyIncome               1.369817
# NumCompaniesWorked          1.026471
# YearsInCurrentRole          0.917363
# JobLevel                    1.025401
# YearsAtCompany              1.764529
# JobInvolvement             -0.498419
# EnvironmentSatisfaction    -0.321654
# Education                  -0.289681
# PercentSalaryHike           0.821128
# YearsSinceLastPromotion     1.984290
# MonthlyRate                 0.018578
# YearsWithCurrManager        0.833451
# TotalWorkingYears           1.117172
# JobSatisfaction            -0.329672
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# PerformanceRating           1.921883
# Age                         0.413286
# HourlyRate                 -0.032311
# RelationshipSatisfaction   -0.302828
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# dtype: float64

# %% [markdown]
# skewness is less and outliers are also less.

# %%
#Using zscore
import numpy as np
from scipy.stats import zscore

z=np.abs(zscore(num))
threshold=3
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                    1          2  Life Sciences                        2
# 1                    8          1  Life Sciences                        3
# 2                    2          2          Other                        4
# 3                    3          4  Life Sciences                        4
# 4                    2          1        Medical                        1
# ...                ...        ...            ...                      ...
# 1465                23          2        Medical                        3
# 1466                 6          1        Medical                        4
# 1467                 4          3  Life Sciences                        2
# 1468                 2          3        Medical                        4
# 1469                 8          3        Medical                        2
#
#       Gender  HourlyRate  JobInvolvement  JobLevel                    JobRole  \
# 0     Female          94               3         2            Sales Executive
# 1       Male          61               2         2         Research Scientist
# 2       Male          92               2         1      Laboratory Technician
# 3     Female          56               3         1         Research Scientist
# 4       Male          40               3         1      Laboratory Technician
# ...      ...         ...             ...       ...                        ...
# 1465    Male          41               4         2      Laboratory Technician
# 1466    Male          42               2         3  Healthcare Representative
# 1467    Male          87               4         2     Manufacturing Director
# 1468    Male          63               2         2            Sales Executive
# 1469    Male          82               4         2      Laboratory Technician
#
#       JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                   4        Single           5993        19479
# 1                   2       Married           5130        24907
# 2                   3        Single           2090         2396
# 3                   3       Married           2909        23159
# 4                   2       Married           3468        16632
# ...               ...           ...            ...          ...
# 1465                4       Married           2571        12290
# 1466                1       Married           9991        21457
# 1467                2       Married           6142         5174
# 1468                2       Married           5390        13243
# 1469                3       Married           4404        10228
#
#       NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0                      8      Y      Yes                 11
# 1                      1      Y       No                 23
# 2                      6      Y      Yes                 15
# 3                      1      Y      Yes                 11
# 4                      9      Y       No                 12
# ...                  ...    ...      ...                ...
# 1465                   4      Y       No                 17
# 1466                   4      Y       No                 15
# 1467                   1      Y      Yes                 20
# 1468                   2      Y       No                 14
# 1469                   2      Y       No                 12
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     3                         1                 0
# 1                     4                         4                 1
# 2                     3                         2                 0
# 3                     3                         3                 0
# 4                     3                         4                 1
# ...                 ...                       ...               ...
# 1465                  3                         3                 1
# 1466                  3                         1                 1
# 1467                  4                         2                 1
# 1468                  3                         4                 0
# 1469                  3                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1387 rows x 32 columns]

# %%
print("columns before applying zscore: ",len(df))
print("columns after applying zscore: ",len(df_new))
# Out:
# columns before applying zscore:  1470
# columns after applying zscore:  1387

# %%
df=df_new
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                    1          2  Life Sciences                        2
# 1                    8          1  Life Sciences                        3
# 2                    2          2          Other                        4
# 3                    3          4  Life Sciences                        4
# 4                    2          1        Medical                        1
# ...                ...        ...            ...                      ...
# 1465                23          2        Medical                        3
# 1466                 6          1        Medical                        4
# 1467                 4          3  Life Sciences                        2
# 1468                 2          3        Medical                        4
# 1469                 8          3        Medical                        2
#
#       Gender  HourlyRate  JobInvolvement  JobLevel                    JobRole  \
# 0     Female          94               3         2            Sales Executive
# 1       Male          61               2         2         Research Scientist
# 2       Male          92               2         1      Laboratory Technician
# 3     Female          56               3         1         Research Scientist
# 4       Male          40               3         1      Laboratory Technician
# ...      ...         ...             ...       ...                        ...
# 1465    Male          41               4         2      Laboratory Technician
# 1466    Male          42               2         3  Healthcare Representative
# 1467    Male          87               4         2     Manufacturing Director
# 1468    Male          63               2         2            Sales Executive
# 1469    Male          82               4         2      Laboratory Technician
#
#       JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                   4        Single           5993        19479
# 1                   2       Married           5130        24907
# 2                   3        Single           2090         2396
# 3                   3       Married           2909        23159
# 4                   2       Married           3468        16632
# ...               ...           ...            ...          ...
# 1465                4       Married           2571        12290
# 1466                1       Married           9991        21457
# 1467                2       Married           6142         5174
# 1468                2       Married           5390        13243
# 1469                3       Married           4404        10228
#
#       NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0                      8      Y      Yes                 11
# 1                      1      Y       No                 23
# 2                      6      Y      Yes                 15
# 3                      1      Y      Yes                 11
# 4                      9      Y       No                 12
# ...                  ...    ...      ...                ...
# 1465                   4      Y       No                 17
# 1466                   4      Y       No                 15
# 1467                   1      Y      Yes                 20
# 1468                   2      Y       No                 14
# 1469                   2      Y       No                 12
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     3                         1                 0
# 1                     4                         4                 1
# 2                     3                         2                 0
# 3                     3                         3                 0
# 4                     3                         4                 1
# ...                 ...                       ...               ...
# 1465                  3                         3                 1
# 1466                  3                         1                 1
# 1467                  4                         2                 1
# 1468                  3                         4                 0
# 1469                  3                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1387 rows x 32 columns]

# %% [markdown]
# very less skewness so not applying power transform

# %% [markdown]
# # Dealing with categorical data

# %%
#label encoding on Attrition(label)
from sklearn.preprocessing import LabelEncoder
lab_enc=LabelEncoder()
df=df.apply(LabelEncoder().fit_transform)

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      23          1               2        605           2                 0
# 1      31          0               1        108           1                 7
# 2      19          1               2        783           1                 1
# 3      15          0               1        798           1                 2
# 4       9          0               2        298           1                 1
# ...   ...        ...             ...        ...         ...               ...
# 1465   18          0               1        476           1                22
# 1466   21          0               2        312           1                 5
# 1467    9          0               2         39           1                 3
# 1468   31          0               1        561           2                 1
# 1469   16          0               2        321           1                 7
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0             1               1                        1       0          64
# 1             0               1                        2       1          31
# 2             1               4                        3       1          62
# 3             3               1                        3       0          26
# 4             0               3                        0       1          10
# ...         ...             ...                      ...     ...         ...
# 1465          1               3                        2       1          11
# 1466          0               3                        3       1          12
# 1467          2               1                        1       1          57
# 1468          2               3                        3       1          33
# 1469          2               3                        1       1          52
#
#       JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0                  2         1        7                3              2
# 1                  1         1        6                1              1
# 2                  1         0        2                2              2
# 3                  2         0        6                2              1
# 4                  2         0        2                1              1
# ...              ...       ...      ...              ...            ...
# 1465               3         1        2                3              1
# 1466               1         2        0                0              1
# 1467               3         1        4                1              1
# 1468               1         1        7                1              1
# 1469               3         1        2                2              1
#
#       MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  OverTime  \
# 0               805          946                   8       0         1
# 1               678         1259                   1       0         0
# 2                62           15                   6       0         1
# 3               312         1166                   1       0         1
# 4               397          806                   9       0         0
# ...             ...          ...                 ...     ...       ...
# 1465            209          568                   4       0         0
# 1466           1060         1065                   4       0         0
# 1467            817          158                   1       0         1
# 1468            726          608                   2       0         0
# 1469            552          453                   2       0         0
#
#       PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                     0                  0                         0
# 1                    12                  1                         3
# 2                     4                  0                         1
# 3                     0                  0                         2
# 4                     1                  0                         3
# ...                 ...                ...                       ...
# 1465                  6                  0                         2
# 1466                  4                  0                         0
# 1467                  9                  1                         1
# 1468                  3                  0                         3
# 1469                  1                  0                         0
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                   0               6                   4
# 1                   2              10                   7
# 2                   2               0                   0
# 3                   2               8                   7
# 4                   2               2                   2
# ...               ...             ...                 ...
# 1465                2               5                   2
# 1466                2               7                   7
# 1467                2               6                   2
# 1468                1               9                   6
# 1469                3               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1387 rows x 32 columns]

# %% [markdown]
# # Relationship between continous features and label

# %% [markdown]
# continous features :
#
# 'Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'

# %%
#visualising the relationship- scatter plot 
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in num:
    if plotnumber<=15:
        X=plt.subplot(5,3,plotnumber)
        plt.scatter(num[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Average price',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Observation:
#
# 1.Daily rates have no much effect on attrition
#
# 2.also distance from hom has less impact on attrtion, however sometimes if its more than 700 distance then attrtion becomes yes
#
# 3.there is less impact of Job satisfaction,PercentSalaryHike,Job involvement, environmental satisfaction,education.stockoptionlevel and monthly income
#
# 4.As monethly income increased that 12,000 the attrition decreased
#
# 5.as years in current role went above 15, then attrition increased
#
# 6.when years with current manager increased beyond 11years, then attrition also increased

# %% [markdown]
# # checking for class imbalance

# %%
print("labels count: \n ",df["Attrition"].value_counts())
# Out:
# labels count:
#   0    1158
# 1     229
# Name: Attrition, dtype: int64

# %%
df["Attrition"].hist(grid=True)
plt.title("Yes vs No")
plt.show()

# %% [markdown]
# Our class is highly imbalanced, hence needs to be balanced

# %% [markdown]
# # balancing class

# %%
# class count
class_count_0, class_count_1 = df['Attrition'].value_counts()

# %%
#Separate class
class_0 = df[df['Attrition'] == 0]
class_1 = df[df['Attrition'] == 1]

print('class 0:', class_0.shape)
print('class 1:', class_1.shape)
# Out:
# class 0: (1158, 32)
# class 1: (229, 32)

# %%
class_0_under = class_0.sample(class_count_1)

test_under = pd.concat([class_0_under, class_1], axis=0)

print("total class of 1 and0:",test_under['Attrition'].value_counts())# plot the count after under-sampeling
test_under['Attrition'].value_counts().plot(kind='bar', title='count (target)')
# Out:
# total class of 1 and0: 1    229
# 0    229
# Name: Attrition, dtype: int64
# <AxesSubplot:title={'center':'count (target)'}>

# %% [markdown]
# hence our classes are now balanced

# %% [markdown]
# # Checking for Multicollinearity

# %% [markdown]
# Checking multicollineairty with vif and heatmap

# %%
#vif
x=df.drop(columns=["Attrition"])
y=df['Attrition']

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

scaler=StandardScaler()
x_scaler=scaler.fit_transform(x)

vif=pd.DataFrame()
vif["quality"]=[variance_inflation_factor(x_scaler,i) for i in range(x_scaler.shape[1])]
vif["feature"]=x.columns
vif
# Out:
#      quality                   feature
# 0   1.849594                       Age
# 1   1.013633            BusinessTravel
# 2   1.028746                 DailyRate
# 3   2.091601                Department
# 4   1.015281          DistanceFromHome
# 5   1.065251                 Education
# 6   1.021662            EducationField
# 7   1.024014   EnvironmentSatisfaction
# 8   1.023735                    Gender
# 9   1.021247                HourlyRate
# 10  1.019071            JobInvolvement
# 11  5.832702                  JobLevel
# 12  1.991250                   JobRole
# 13  1.022450           JobSatisfaction
# 14  1.839009             MaritalStatus
# 15  4.796330             MonthlyIncome
# 16  1.019480               MonthlyRate
# 17  1.275052        NumCompaniesWorked
# 18       NaN                    Over18
# 19  1.028915                  OverTime
# 20  2.482129         PercentSalaryHike
# 21  2.477837         PerformanceRating
# 22  1.020540  RelationshipSatisfaction
# 23  1.820982          StockOptionLevel
# 24  3.814566         TotalWorkingYears
# 25  1.027567     TrainingTimesLastYear
# 26  1.017545           WorkLifeBalance
# 27  4.944787            YearsAtCompany
# 28  3.049386        YearsInCurrentRole
# 29  1.437048   YearsSinceLastPromotion
# 30  3.332390      YearsWithCurrManager

# %% [markdown]
# All are less than 5 hence less multicollinearity

# %%
data_corr=df.corr()
sns.heatmap(data_corr, annot = True)
plt.show()

# %% [markdown]
# Multicollinearity is not seen

# %% [markdown]
# # PCA

# %%
#standardising the data for PCA
x=df.drop(columns=["Attrition"])
y=df['Attrition']

from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaledX=scaler.fit_transform(x)

#PCA
from sklearn.decomposition import PCA

testpca=PCA()
Y=testpca.fit(scaledX)

var_cumu=np.cumsum(Y.explained_variance_ratio_)*100

var_cumu
# Out:
# array([ 14.00051562,  21.0680581 ,  27.11536518,  32.88057055,
#         38.28932338,  42.14410814,  45.97334142,  49.70841644,
#         53.3527216 ,  56.94062843,  60.41874101,  63.82924961,
#         67.15781324,  70.37449273,  73.55486507,  76.66994509,
#         79.67443949,  82.62983076,  85.49104814,  88.29123098,
#         90.78900617,  92.76254633,  94.70319701,  95.79374421,
#         96.81040644,  97.67814449,  98.47442298,  99.19126858,
#         99.66841444, 100.        , 100.        ])

# %%
# PCs explaines 99% of the variance?
k=np.argmax(var_cumu>95)
print("Number of components explaining 99% variance: ",k)
# Out:
# Number of components explaining 99% variance:  23

# %%
plt.ylabel('Cumilative explained variance')
plt.xlabel('Principal components')
plt.axvline(x=k,color='k',linestyle='--')
plt.axhline(y=99,color='r',linestyle='--')

plt.plot(var_cumu)
plt.show()

# %%
# Creating final dataset with 30 columns

FinalPCA=PCA(n_components=6)
FinalData=FinalPCA.fit_transform(scaledX)

FinalData2=pd.DataFrame(FinalData)
FinalData2
# Out:
#              0         1         2         3         4         5
# 0     0.147607  0.822121 -2.185954 -1.531650  0.247391 -1.636812
# 1     1.085704 -0.933408  2.605334 -1.584164  0.102045  0.615431
# 2    -2.793785  1.187959 -0.268330 -0.042438 -1.368304  1.660033
# 3    -0.571469 -0.821426 -1.086602  0.513003 -0.453328  0.560009
# 4    -1.813093  0.814653 -0.101532  1.222680 -1.037322  0.234077
# ...        ...       ...       ...       ...       ...       ...
# 1382 -0.561582  0.770991  0.842047  0.779258 -0.367189 -0.168456
# 1383  1.452911  0.153154  0.398534  0.928292 -1.115551  3.031408
# 1384 -0.892689 -0.035344  2.306270 -1.033120  0.476442 -1.882023
# 1385  1.562175 -0.293887 -1.373191 -0.661033  0.320823  0.360086
# 1386 -0.942251  0.226643 -0.411805  0.874062 -0.932834 -0.479769
#
# [1387 rows x 6 columns]

# %%
df=FinalData2

# %%
#analysing data
df.describe()
# Out:
#                   0             1             2             3             4  \
# count  1.387000e+03  1.387000e+03  1.387000e+03  1.387000e+03  1.387000e+03
# mean  -1.312737e-17 -4.226372e-17  1.088611e-17  7.772362e-17  1.136638e-16
# std    2.050167e+00  1.456542e+00  1.345149e+00  1.315302e+00  1.273876e+00
# min   -3.934407e+00 -3.816509e+00 -2.568694e+00 -3.970002e+00 -3.569014e+00
# 25%   -1.549692e+00 -1.070895e+00 -9.314975e-01 -8.329121e-01 -9.643626e-01
# 50%   -2.245450e-01 -1.855099e-01 -2.103319e-01  1.198377e-02  4.942758e-02
# 75%    1.466479e+00  9.487401e-01  6.133383e-01  9.349340e-01  8.805425e-01
# max    6.257070e+00  5.289483e+00  4.409285e+00  4.292640e+00  3.643255e+00
#
#                   5
# count  1.387000e+03
# mean  -1.233892e-16
# std    1.070343e+00
# min   -3.091291e+00
# 25%   -7.134111e-01
# 50%    3.452092e-03
# 75%    7.009105e-01
# max    4.379991e+00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1387 entries, 0 to 1386
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1387 non-null   float64
#  1   1       1387 non-null   float64
#  2   2       1387 non-null   float64
#  3   3       1387 non-null   float64
#  4   4       1387 non-null   float64
#  5   5       1387 non-null   float64
# dtypes: float64(6)
# memory usage: 65.1 KB

# %% [markdown]
# # Splitting data

# %%
#scaling
scalar=StandardScaler()
x_scaled=scalar.fit_transform(x)

#splitting data
x_train, x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=10)

# %%
y_train.head()
# Out:
# 1009    0
# 1395    1
# 1010    0
# 504     1
# 1017    0
# Name: Attrition, dtype: int32

# %% [markdown]
# # Finding best random state

# %%
from sklearn.linear_model import LogisticRegression
maxAccu=0
maxRS=0

for i in range(1,200):
    x_train, x_test,y_train, y_test=train_test_split(x_scaled,y,test_size=.25,random_state=i)
    LR=LogisticRegression()
    LR.fit(x_train,y_train)
    predrf=LR.predict(x_test)
    acc=accuracy_score(y_test,predrf)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i

print("Best accuracy is", maxAccu,"on Random State",maxRS)
# Out:
# Best accuracy is 0.9164265129682997 on Random State 109

# %%
 x_train, x_test,y_train, y_test=train_test_split(x_scaled,y,test_size=.25,random_state=109)

# %% [markdown]
# # Modelling

# %%
#modelling

from sklearn.linear_model import LogisticRegression

LR=LogisticRegression()
LR.fit(x_train,y_train)
predlr=LR.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.9164265129682997
# [[295   4]
#  [ 25  23]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       299
#            1       0.85      0.48      0.61        48
#
#     accuracy                           0.92       347
#    macro avg       0.89      0.73      0.78       347
# weighted avg       0.91      0.92      0.91       347

# %%
#modelling
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt=dt.predict(x_test)

print(accuracy_score(y_test,preddt))
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# 0.8040345821325648
# [[258  41]
#  [ 27  21]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88       299
#            1       0.34      0.44      0.38        48
#
#     accuracy                           0.80       347
#    macro avg       0.62      0.65      0.63       347
# weighted avg       0.83      0.80      0.81       347

# %%
#modelling
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)

print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.8876080691642652
# [[299   0]
#  [ 39   9]]
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       299
#            1       1.00      0.19      0.32        48
#
#     accuracy                           0.89       347
#    macro avg       0.94      0.59      0.63       347
# weighted avg       0.90      0.89      0.85       347

# %%
#modelling
from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train,y_train)

ad_pred=svc.predict(x_test)

print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 0.8760806916426513
# [[295   4]
#  [ 39   9]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       299
#            1       0.69      0.19      0.30        48
#
#     accuracy                           0.88       347
#    macro avg       0.79      0.59      0.61       347
# weighted avg       0.86      0.88      0.84       347

# %%
#Finding overfitting
from sklearn.model_selection import cross_val_score

scr=cross_val_score(LR,x,y,cv=5)
print("Cross validation score of Logistic Regression model :", scr.mean())

scr=cross_val_score(dt,x,y,cv=5)
print("Cross validation score of Decision Tree model :", scr.mean())

scr=cross_val_score(rf,x,y,cv=5)
print("Cross validation score of Random Forest model :", scr.mean())

scr=cross_val_score(svc,x,y,cv=5)
print("Cross validation score of SVC model :", scr.mean())
# Out:
# Cross validation score of Logistic Regression model : 0.8363452198529984
# Cross validation score of Decision Tree model : 0.7901721943744644
# Cross validation score of Random Forest model : 0.8550840194270576
# Cross validation score of SVC model : 0.8348959821312626

# %% [markdown]
# Difference is least in DecisionTreeClassifier

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But since there is a class imbalance problem, which even when fixed didnt give a good score using ROC AUC score would be better

# %% [markdown]
# # ROC AUC curve

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import plot_roc_curve

# %%
lr=LogisticRegression()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
kn=KNeighborsClassifier()

# %%
lr.fit(x_train,y_train)
dt.fit(x_train,y_train)
rf.fit(x_train,y_train)
kn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print(lr.score(x_test,y_test))
print(dt.score(x_test,y_test))
print(rf.score(x_test,y_test))
print(kn.score(x_test,y_test))
# Out:
# 0.9164265129682997
# 0.8155619596541787
# 0.8847262247838616
# 0.8703170028818443

# %%
#RandomForestClassifier
roc_auc_score(y_test,rf.predict(x_test))
# Out:
# 0.6008221850613155

# %%
#LogisticRegression
roc_auc_score(y_test,lr.predict(x_test))
# Out:
# 0.732894370122631

# %%
#KNeighborsClassifier
roc_auc_score(y_test,kn.predict(x_test))
# Out:
# 0.5574832775919732

# %%
#DecisionTreeClassifier
roc_auc_score(y_test,dt.predict(x_test))
# Out:
# 0.6656215161649944

# %% [markdown]
# the AUC value lies between 0.5 to 1 where 0.5 denotes a bad classifer and 1 denotes an excellent classifier.
#
# The AUC score shows that Logistic regression is the best classifier among this

# %% [markdown]
# # Reason for going for ROC_AUC is because
#
# 1.accuracy score is calculated on the predicted classes while we calculate ROC AUC on predicted scores.
#
# 2.accuracy looks at fractions of correctly assigned positive and negative classes and since our class is highly imbalanced we get a really high accuracy score by simply predicting that all observations belong to the majority class.

# %% [markdown]
# # Hyperparameter tuning

# %%
#Logistic Regression
paramters={'penalty':['l1', 'l2','elasticnet','none'],
           'dual':[True,False],
           'tol':[0.21,0.50,0.75,1,1.25,1.5],
           'C':[2,3,4,5,6,7,8,9],
           'intercept_scaling':[1.2,2.1,3.1,20.2],
}

# %%
from sklearn.linear_model import LogisticRegression
GCV=GridSearchCV(LogisticRegression(),paramters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [2, 3, 4, 5, 6, 7, 8, 9], 'dual': [True, False],
#                          'intercept_scaling': [1.2, 2.1, 3.1, 20.2],
#                          'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                          'tol': [0.21, 0.5, 0.75, 1, 1.25, 1.5]})

# %%
GCV.best_params_
# Out:
# {'C': 2, 'dual': False, 'intercept_scaling': 1.2, 'penalty': 'l2', 'tol': 1.25}

# %%
mod=LogisticRegression(C=2,dual=False,intercept_scaling=1.2,penalty='l2',tol=0.21)

# %%
mod.fit(x_train,y_train)
pred=mod.predict(x_test)
print(accuracy_score(y_test,pred)*100)
# Out:
# 91.93083573487031

# %% [markdown]
# Accuracy obtained is 91.9 %

# %%
regression=LogisticRegression()
regression.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Saving of model

# %%
#saving LogisticRegression model
LogisticRegression_tree_model=LogisticRegression()
LogisticRegression_tree_model.fit(x_train,y_train)

filename='finalized_model.pickle'
pickle.dump(LogisticRegression_tree_model,open(filename,'wb'))

# %%
y_pred=regression.predict(x_test)

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual chance of admission')
plt.ylabel('predicted chance of admission')
plt.title('actual vs model predicted')
plt.show()

# %% [markdown]
# # Accuracy and ROC AUC score of our model

# %%
scr=cross_val_score(regression,x,y,cv=5)
print("Cross validation score of Logistic Regression model :", scr.mean())
# Out:
# Cross validation score of Logistic Regression model : 0.8363452198529984

# %%
regression.fit(x_train,y_train)
pred=regression.predict(x_test)
print("accuracy score of the Logistic Regression model is",accuracy_score(y_test,pred)*100)
# Out:
# accuracy score of the Logistic Regression model is 91.64265129682997

# %%
regression.fit(x_train,y_train)
print("ROC AUC Score of the logistic regression model is",roc_auc_score(y_test,regression.predict(x_test)))
# Out:
# ROC AUC Score of the logistic regression model is 0.732894370122631

# %% [markdown]
# # Regularisation

# %%
lasscv=LassoCV(alphas=None, max_iter=1000,normalize=True)
lasscv.fit(x_train,y_train)

#best alpha parameter
alpha=lasscv.alpha_

lasso_reg=Lasso(alpha)
lasso_reg.fit(x_train,y_train)

lasso_reg.score(x_test,y_test)
# Out:
# 0.2739944488926309
